# %%
# Enable import from parent directory (src/)
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# ### create instance

# %%
from eda import InsuranceEDA

# %%
eda = InsuranceEDA(data_path="../data/MachineLearningRating_v3.txt")

# %%
eda.load_data(delimiter="|")
# Out:
# [INFO] Loading data...
# c:\Users\bekuman\Desktop\Insurance-Risk-Analysis\src\eda.py:15: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(self.data_path, delimiter=delimiter)
# [INFO] Data loaded successfully with shape: (1000098, 52)

# %%
eda.df
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
eda.data_summary()
# Out:
# [SUMMARY] Descriptive statistics:
#         UnderwrittenCoverID      PolicyID     TransactionMonth  \
# count          1.000098e+06  1.000098e+06              1000098
# unique                  NaN           NaN                   23
# top                     NaN           NaN  2015-08-01 00:00:00
# freq                    NaN           NaN               106747
# mean           1.048175e+05  7.956682e+03                  NaN
# std            6.329371e+04  5.290039e+03                  NaN
# min            1.000000e+00  1.400000e+01                  NaN
# 25%            5.514300e+04  4.500000e+03                  NaN
# 50%            9.408300e+04  7.071000e+03                  NaN
# 75%            1.391900e+05  1.107700e+04                  NaN
# max            3.011750e+05  2.324600e+04                  NaN
#
#        IsVATRegistered Citizenship   LegalType    Title Language  \
# count          1000098     1000098     1000098  1000098  1000098
# ...

# %%
eda.check_missing_values()
# Out:
# [CHECK] Missing values:
# Bank                        145961
# AccountType                  40232
# MaritalStatus                 8259
# Gender                        9536
# mmcode                         552
# VehicleType                    552
# make                           552
# Model                          552
# Cylinders                      552
# cubiccapacity                  552
# kilowatts                      552
# bodytype                       552
# NumberOfDoors                  552
# VehicleIntroDate               552
# CustomValueEstimate         779642
# CapitalOutstanding               2
# NewVehicle                  153295
# WrittenOff                  641901
# Rebuilt                     641901
# Converted                   641901
# CrossBorder                 999400
# NumberOfVehiclesInFleet    1000098
# dtype: int64

# %%
eda.drop_column(column_name="NumberOfVehiclesInFleet")
# Out:
# successfuly dropped NumberOfVehiclesInFleet column

# %%
#eda.univariate_analysis()

# %% [markdown]
# ### bivariate analysis

# %%
eda.bivariate_analysis()
# Out:
# [BIVARIATE] Correlation Matrix for numeric features:
#                           UnderwrittenCoverID  PolicyID  PostalCode    mmcode  \
# UnderwrittenCoverID                  1.000000  0.916324   -0.018206  0.083310
# PolicyID                             0.916324  1.000000   -0.034186  0.074428
# PostalCode                          -0.018206 -0.034186    1.000000  0.100995
# mmcode                               0.083310  0.074428    0.100995  1.000000
# RegistrationYear                     0.065886  0.067192    0.009472 -0.088748
# Cylinders                           -0.026910 -0.028551   -0.042656 -0.100871
# cubiccapacity                        0.084892  0.088083   -0.139570  0.196766
# kilowatts                           -0.038613 -0.032198   -0.195637  0.033500
# NumberOfDoors                       -0.023781 -0.031438    0.083857  0.021488
# CustomValueEstimate                  0.006728  0.005268   -0.014861 -0.003286
# ...

# %% [markdown]
# ### the overall Loss Ratio

# %%
eda.loss_ratio_analysis()
# Out:
# [LOSS RATIO] Grouped Loss Ratios:
#
# Loss Ratio by Province:
#  Province
# Free State       11.060304
# KwaZulu-Natal     4.739752
# Gauteng           3.849419
# North West        2.457664
# Limpopo           1.242700
# Western Cape      1.057307
# Eastern Cape      0.486535
# Mpumalanga        0.404356
# Northern Cape     0.116388
# Name: LossRatio, dtype: float64
# Loss Ratio by VehicleType:
#  VehicleType
# Bus                  12.024865
# Passenger Vehicle     3.091713
# Medium Commercial     1.929193
# Heavy Commercial      1.434407
# Light Commercial      0.364845
# Name: LossRatio, dtype: float64
# Loss Ratio by Gender:
#  Gender
# Male             3.749183
# Not specified    3.021680
# Female           0.687402
# Name: LossRatio, dtype: float64

# %% [markdown]
# ### the monthly changes TotalPremium and TotalClaims

# %%
eda.time_trend_analysis()
# Out:
# [TIME TREND] Claims and Premium over Time

# %%
eda.vehicle_risk_analysis()
# Out:
# [VEHICLE RISK] Analyzing Claim by Vehicle Make/Model
#
# Top 10 Models by Total Claims:
#                make                             Model   TotalClaims
# 321         TOYOTA         QUANTUM 2.7 SESFIKILE 16s  1.203750e+07
# 320         TOYOTA         QUANTUM 2.7 SESFIKILE 15s  1.151173e+07
# 319         TOYOTA         QUANTUM 2.7 SESFIKILE 14s  9.967764e+06
# 315         TOYOTA    QUANTUM 2.5 D-4D SESFIKILE 16s  7.733236e+06
# 308         TOYOTA             HiACE SUPER 16 F/Lift  3.275205e+06
# 305         TOYOTA                      HiACE SIYAYA  1.727756e+06
# 313         TOYOTA          QUANTUM 2.5 D-4D 14 SEAT  1.339541e+06
# 45             CMC                       AMANDLA 2.2  1.106007e+06
# 259         TOYOTA                     AVANZA 1.5 SX  1.089785e+06
# 179  MERCEDES-BENZ  SPRINTER 515 CDi HI-ROOF F/C P/V  8.874161e+05
#
# Bottom 10 Models by Total Claims:
#                                      make  \
# 145                        MERCEDES-BENZ
# ...

# %%
eda.detect_outliers()
# Out:
# [OUTLIERS] Using box plots for outlier detection...

# %%
eda.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  datetime64[ns]
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...
